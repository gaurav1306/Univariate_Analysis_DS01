# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
dataset = pd.read_csv("Melbourne_housing_FULL.csv")

# %%
dataset
# Out:
#                    Suburb              Address  Rooms Type      Price Method  \
# 0              Abbotsford        68 Studley St      2    h        NaN     SS
# 1              Abbotsford         85 Turner St      2    h  1480000.0      S
# 2              Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3              Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 4              Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5              Abbotsford     40 Federation La      3    h   850000.0     PI
# 6              Abbotsford          55a Park St      4    h  1600000.0     VB
# 7              Abbotsford         16 Maugie St      4    h        NaN     SN
# 8              Abbotsford         53 Turner St      2    h        NaN      S
# 9              Abbotsford         99 Turner St      2    h        NaN      S
# 10             Abbotsford       129 Charles St      2    h   941000.0      S
# ...

# %%
new_data = dataset.fillna(method = 'pad')

# %%
new_data
# Out:
#                    Suburb              Address  Rooms Type      Price Method  \
# 0              Abbotsford        68 Studley St      2    h        NaN     SS
# 1              Abbotsford         85 Turner St      2    h  1480000.0      S
# 2              Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3              Abbotsford   18/659 Victoria St      3    u  1035000.0     VB
# 4              Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5              Abbotsford     40 Federation La      3    h   850000.0     PI
# 6              Abbotsford          55a Park St      4    h  1600000.0     VB
# 7              Abbotsford         16 Maugie St      4    h  1600000.0     SN
# 8              Abbotsford         53 Turner St      2    h  1600000.0      S
# 9              Abbotsford         99 Turner St      2    h  1600000.0      S
# 10             Abbotsford       129 Charles St      2    h   941000.0      S
# ...

# %%
boolseries = pd.isnull(new_data["Price"])

# %%
new_data[boolseries]
# Out:
#        Suburb        Address  Rooms Type  Price Method SellerG       Date  \
# 0  Abbotsford  68 Studley St      2    h    NaN     SS  Jellis  3/09/2016
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0  ...       1.0  1.0     126.0           NaN        NaN
#
#           CouncilArea Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
#
# [1 rows x 21 columns]

# %%
clean_data = new_data.drop(new_data.index[0])

# %%
clean_data
# Out:
#                    Suburb              Address  Rooms Type      Price Method  \
# 1              Abbotsford         85 Turner St      2    h  1480000.0      S
# 2              Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3              Abbotsford   18/659 Victoria St      3    u  1035000.0     VB
# 4              Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5              Abbotsford     40 Federation La      3    h   850000.0     PI
# 6              Abbotsford          55a Park St      4    h  1600000.0     VB
# 7              Abbotsford         16 Maugie St      4    h  1600000.0     SN
# 8              Abbotsford         53 Turner St      2    h  1600000.0      S
# 9              Abbotsford         99 Turner St      2    h  1600000.0      S
# 10             Abbotsford       129 Charles St      2    h   941000.0      S
# 11             Abbotsford         124 Yarra St      3    h  1876000.0      S
# ...

# %%
clean_data.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.371458  0.271482  0.085878  0.732008  0.461273
# Price          0.371458  1.000000 -0.195709  0.051967  0.272854  0.285294
# Distance       0.271482 -0.195709  1.000000  0.481556  0.247095  0.116904
# Postcode       0.085878  0.051967  0.481556  1.000000  0.083840  0.113360
# Bedroom2       0.732008  0.272854  0.247095  0.083840  1.000000  0.621338
# Bathroom       0.461273  0.285294  0.116904  0.113360  0.621338  1.000000
# Car            0.309854  0.125892  0.217338  0.059230  0.386133  0.299401
# Landsize       0.033058  0.019428  0.050213  0.029301  0.038304  0.033333
# BuildingArea   0.110164  0.086115  0.065198  0.042675  0.138757  0.143817
# YearBuilt      0.036722 -0.167365  0.243453  0.060205  0.025148  0.103220
# Lattitude     -0.005087 -0.186050 -0.104385 -0.238713 -0.031681 -0.118740
# Longtitude     0.097138  0.170078  0.199657  0.341987  0.119045  0.126633
# ...

# %%
feature = dataset['Rooms']
target_var = dataset['Price']

def line(m,x,c):
    return m*x+c;

def error(m,x,c,y):
    return np.mean((m*x+c-y)**2)

def derivative_slope(m,x,c,y):
    return 2 * (np.mean(m*x+c-y) * x)

def derivative_intercept(m,x,c,y):
    return 2 * (np.mean(m*x+c-y) * 1)

def accuracy_prediction(current_error,y):
    return 100- ((current_error/np.mean(y)**2) * 100)

# %%
m = random.random()
c = random.random()
cost = []
alpha = 0.001
for i in range(0,1000):
    m = m - alpha * (derivative_slope(m,feature,c,target_var))
    c = c - alpha * (derivative_intercept(m,feature,c,target_var))
    cost.append(error(m,feature,c,target_var))

plt.plot(cost)
plt.show()

# %%
print("Your Algo achieved: ",accuracy_prediction(error(m,feature,c,target_var),target_var), "%" )
# Out:
# Your Algo achieved:  59.19820026225557 %

# %%
predicted_answers = line(m,feature,c)
plt.scatter(feature,target_var)
plt.plot(feature,predicted_answers)
plt.show()
